# %%
from pylab import mpl
import pandas as pd
import talib
mpl.rcParams['font.sans-serif']=['KaiTi']
mpl.rcParams['axes.unicode_minus']=False
df = pd.read_csv("sh.600585"+"_k_data.csv",header=0,index_col=0)

# %%
df.head()
# Out:
#                  code   open   high    low  close  preclose    volume  \
# date
# 2019-01-02  sh.600585  29.30  29.40  28.56  28.82     29.28  19145382
# 2019-01-03  sh.600585  28.69  29.01  28.05  28.23     28.82  17388802
# 2019-01-04  sh.600585  27.77  28.52  27.23  28.40     28.23  36319551
# 2019-01-07  sh.600585  28.70  29.03  28.39  29.02     28.40  25508310
# 2019-01-08  sh.600585  28.91  29.29  28.66  29.05     29.02  16903578
#
#                   amount  adjustflag      turn  tradestatus    pctChg  isST
# date
# 2019-01-02  5.517840e+08           3  0.478670            1 -1.571042     0
# 2019-01-03  4.948543e+08           3  0.434752            1 -2.047190     0
# 2019-01-04  1.014467e+09           3  0.908056            1  0.602197     0
# 2019-01-07  7.324002e+08           3  0.637755            1  2.183101     0
# 2019-01-08  4.901516e+08           3  0.422621            1  0.103373     0
